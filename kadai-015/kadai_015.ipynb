# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(self.name)
        print(self.age)


# Humanクラスのインスタンスを変数に代入
human1 = Human("太郎", 20)

# メソッドを使って名前と年齢を出力
human1.printinfo()
# Out:
# 太郎
# 20
