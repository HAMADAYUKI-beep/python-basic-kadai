# %%
array = [
    "月曜日は晴れです",
    "火曜日は雨です",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

# %%
print(array[2])
# Out:
# 水曜日は晴れです

# %%
水曜日は晴れです
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2383144823.py in <cell line: 0>()
# ----> 1 水曜日は晴れです
#
# NameError: name '水曜日は晴れです' is not defined

# %%
dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

# %%
print(dictionary["wed"])

# %%
晴れ
